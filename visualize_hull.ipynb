# %% [markdown]
# Runs the alpha-hull giftwrapping algorithm to define the interior of the protein to search with CARPdock.
# Enables checking the value of alpha corresponds to the search space you want to search.

# %%
import torch
from utils.burial_calc import plot_alpha_shape, compute_alpha_hull
from carp_dock import compute_test_points
import prody as pr


alpha = 9.0
points = pr.parsePDB('/nfs/polizzi/bfry/programs/CARPdock/exatecan_ntf2_screen-amine_exposed/carpdock_out/cluster_00_sup/cluster_1_515.pdb').ca.getCoords()
test_points = compute_test_points(torch.from_numpy(points), torch.device('cpu'), max_batch_size=1000, search_box_padding=5.0, verbose=True, alpha=alpha, grid_width=2.5)

triangles = compute_alpha_hull(points, alpha)
plot_alpha_shape(points, triangles, test_points, no_plot=True)
# Out:
# Computed 5865 initial test grid points
# Filtered to 588, points
